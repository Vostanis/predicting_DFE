# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
0.975 / (pow(1.025, 2) * 1)
# Out:
# 0.9280190362879239

# %%
i = np.geomspace(1, 36_000, 3000)
# exp is in [0.95, 1.05]

upper_var = 1.025 / (0.975 * 0.975 * d)
lower_var = 0.975 / (1.025 * 1.025 * d)

sns.lineplot(upper_var, color='red')
sns.lineplot(lower_var, color='blue')
plt.show()

# sns.line
