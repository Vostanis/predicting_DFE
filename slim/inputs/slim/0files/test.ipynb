# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### Change code here with the fitness function

# %%
arr = np.random.uniform(low=-0.003, high=0.003, size=10000)
arr
# df = pd.DataFrame(arr).set_index(0)
# Out:
# array([-2.79864321e-03, -9.60562231e-04,  7.21232849e-04, ...,
#         2.75213207e-03,  1.99683290e-03, -7.94673715e-05], shape=(10000,))

# %%
df.to_csv('./targets.csv')
